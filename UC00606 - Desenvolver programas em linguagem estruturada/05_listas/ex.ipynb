# %% [markdown]
# 1 Faça um programa para imprimir:
#
#     1
#     2   2
#     3   3   3
#     .....
#     n   n   n   n   n   n  ... n
#
# para um n informado pelo usuário.
#
# Use uma função que receba um valor n inteiro e imprima até a n-ésima linha.

# %%
def ex1(n):
    for i in range(1, n + 1):
        print(f"{i} " * i)


ex1(3)
# Out:
# 1
# 2 2
# 3 3 3

# %% [markdown]
# 2 Faça um programa para imprimir:  for -> for
#
#     1
#     1   2
#     1   2   3
#     .....
#     1   2   3   ...  n
#
# para um n informado pelo usuário.
#
# Use uma função que receba um valor n inteiro e imprima até a n-ésima linha.

# %%
lst = []

# %%
for i in range(1_000_000):
    lst.insert(0, i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 for i in range(1_000_000):
# ----> 2     lst.insert(0, i)
#
# KeyboardInterrupt:

# %%
lst.__len__()
# Out:
# 0

# %%
import random

n = 100
saidas = [0, 0, 0, 0, 0, 6]

# %%
for _ in range(n):
    num = random.randint(1, 6)
    saidas[num - 1] += 1

# %%
saidas
# Out:
# [36, 32, 35, 29, 38, 36]

# %%
[17, 13, 12, 23, 15, 26]
[17, 13, 12, 23, 15, 26]
[17, 13, 12, 23, 15, 26]

# %% [markdown]
# [33, 30, 36, 36, 33, 38]

# %%
sum(saidas)
# Out:
# 100

# %% [markdown]
# Faça um Programa que leia uma palavra de 10 caracteres, e diga quantas consoantes foram lidas.
# guarde as consoantes numa lista. No final Imprima as consoantes.
#
# consoantes <=> nao vogal
#
# Extra: validar se a palavra tem 10 caracteres

# %%
# var como vogais

vogais = "aeiou"  # ["a", "e", "i", "o", "u"]

# lista consoantes
consoantes = []

# ler a palavra

palavra = input("Digite uma palavra com 10chars: ")

# validar e são so letras
# validar se tem 10 caracteres

if palavra.isalpha() and palavra.__len__() == 10:
    for letra in palavra:
        if letra.lower() not in vogais:
            consoantes.append(letra)
else:
    print("Palavra invalida:", palavra)

print(f"foram lidas {consoantes.__len__()} consoantes")
print(f"foram lidas {len(consoantes)} consoantes")

for i, letra in enumerate(consoantes):
    print(f"a {i + 1}ª consoante foi {letra}")
# Out:
# foram lidas 8 consoantes
# foram lidas 8 consoantes
# a 1 consoante foi q
# a 2 consoante foi z
# a 3 consoante foi w
# a 4 consoante foi s
# a 5 consoante foi x
# a 6 consoante foi d
# a 7 consoante foi c
# a 8 consoante foi r

# %%
wrd = ""
vgs = "aeiou"
cns = list()

while len(wrd) != 10:
    wrd = input("introduza uma palavra de 10 letras: ")

for ltr in wrd:
    if not ltr.isalpha():
        print("a palavra contem caracter inválido")
        exit()

    if ltr not in vgs:
        cns.append(ltr)

print(len(cns))
print(cns)

# %%
# Out:
# 6
# 6
# 2
# 6
# 3
# 1
# 3
# 3
# 5
# 3
