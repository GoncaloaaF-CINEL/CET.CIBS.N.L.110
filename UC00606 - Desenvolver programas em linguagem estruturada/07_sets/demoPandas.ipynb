# %%
import pandas as pd

# %%
df = pd.read_csv("net_speedtest.csv")
df
# Out:
#        2018-09-17 19:07:15  14.11  35.0  9.58
# 0      2018-09-17 19:08:34  13.00  36.7  9.68
# 1      2018-09-17 19:10:40  13.06  31.4  9.92
# 2      2018-09-17 19:12:34  13.87  36.5  9.82
# 3      2018-09-17 19:14:34  13.29  31.2  9.56
# 4      2018-09-17 19:16:35  13.99  36.4  9.89
# ...                    ...    ...   ...   ...
# 21504  2018-10-17 18:32:33  11.97  36.5  9.80
# 21505  2018-10-17 18:32:33  11.97  36.5  9.80
# 21506  2018-10-17 18:32:33  11.97  36.5  9.80
# 21507  2018-10-17 18:32:33  11.97  36.5  9.80
# 21508                  NaN    NaN   NaN   NaN
#
# [21509 rows x 4 columns]

# %%
df.size
# Out:
# 86036

# %%
df.drop_duplicates(inplace=True)

# %%
df.size
# Out:
# 85980
