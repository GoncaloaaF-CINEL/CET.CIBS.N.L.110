# %%
import re
import ipaddress

# %%
ip = "255.0.0.0"
try:
    val = ipaddress.IPv4Address(ip)
    print(True)
except:
    print(False)
# Out:
# True

# %%
# ip = "fe80::1ff:fe23:4567:890a"
ip = "255.0.0.0"
try:
    val = ipaddress.ip_address(ip) ## validar
    print(True)
except:
    print(False)
# Out:
# True

# %%
ipaddress.ip_network('192.168.2.0/24')
# Out:
# IPv4Network('192.168.2.0/24')

# %%
ipaddress.ip_interface("192.168.20.0/24")
# Out:
# IPv4Interface('192.168.20.0/24')
