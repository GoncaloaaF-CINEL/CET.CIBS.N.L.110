# %%
import pandas as pd

# %%
df = pd.read_csv("HealthApp_2k.csv", delimiter=";")
df.head()
# Out:
#                     Data                        c2        c3  \
# 0  20171223-22:15:29:606                  Step_LSC  30002312
# 1  20171223-22:15:29:615                  Step_LSC  30002312
# 2  20171223-22:15:29:633  Step_StandReportReceiver  30002312
# 3  20171223-22:15:29:635                  Step_LSC  30002312
# 4  20171223-22:15:29:635     Step_StandStepCounter  30002312
#
#                                                   c4  c5  c6  c7
# 0                            onStandStepChanged 3579 NaN NaN NaN
# 1                      onExtend:1514038530000 14 0 4 NaN NaN NaN
# 2  onReceive action: android.intent.action.SCREEN_ON NaN NaN NaN
# 3  processHandleBroadcastAction action:android.in... NaN NaN NaN
# 4                                  flush sensor data NaN NaN NaN

# %%
df.Data.head()
# Out:
# 0   2017-12-23 22:15:29.606
# 1   2017-12-23 22:15:29.615
# 2   2017-12-23 22:15:29.633
# 3   2017-12-23 22:15:29.635
# 4   2017-12-23 22:15:29.635
# Name: Data, dtype: datetime64[us]

# %%
df.dtypes

# %%
#                                        20171223-22:15:29:606
df.Data = pd.to_datetime(df.Data, format="%Y%m%d-%H:%M:%S:%f")

# %%
df.dtypes
# Out:
# Data    datetime64[us, UTC]
# c2                      str
# c3                    int64
# c4                      str
# c5                  float64
# c6                  float64
# c7                  float64
# dtype: object
