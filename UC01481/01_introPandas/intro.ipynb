# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes.csv")

# %%
dados = {
    "nome": ["Ana", "Bruno", "Carlos", "Diana", "Eduardo", "Filipa"],
    "idade": [22, 25, 21, 24, 23, 26],
    "curso": ["Python", "Java", "Python", "C#", "Python", "Java"],
    "nota": [17, 14, 12, 18, 10, 16],
    "horas_estudo": [20, 15, 10, 25, 8, 18]
}

# %%
_ = pd.DataFrame(dados)

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.dtypes

# %%
df2 = pd.read_csv("client_hostname.csv")
df2.head()

# %%
df2.dtypes

# %%
df2.info()

# %%
df.describe()

# %%
df2.describe()

# %%
df.shape

# %%
df2.shape

# %%
df.columns

# %%
df.index

# %%
type(df)

# %%
df.Age

# %%
df["Age"]

# %%
df2 = pd.read_csv("client_hostname.csv")
df2.head()

# %%
alList = df2["alias list"]

# %%
type(alList)

# %%
df.Age.min()

# %%
df.Age.max()

# %%
df.Age.mean()

# %%
df.Age.std()

# %%
df.Age.sum()

# %%
df.max()

# %%
df2.nunique()

# %%
df2.address_list.nunique()

# %%
df2["alias list"].unique().tolist()

# %%
pd.Series(df2["alias list"].unique())

# %%
df2["alias list"].value_counts()

# %%
df2.value_counts()

# %%
dados = {
    "nome": ["Ana", "Bruno", "Carlos", "Diana", "Eduardo", "Filipa"],
    "idade": [22, 25, 21, 24, 23, 26],
    "curso": ["Python", "Java", "Python", "C#", "Python", "Java"],
    "nota": [17, 14, 12, 18, 10, 16],
    "horas_estudo": [20, 15, 10, 25, 8, 18]
}
df = pd.DataFrame(dados)

# %%
df
# Out:
#       nome  idade   curso  nota  horas_estudo
# 0      Ana     22  Python    17            20
# 1    Bruno     25    Java    14            15
# 2   Carlos     21  Python    12            10
# 3    Diana     24      C#    18            25
# 4  Eduardo     23  Python    10             8
# 5   Filipa     26    Java    16            18

# %%
df[["idade", "nome"]]

# %%
type(df[["idade"]])
# Out:
# pandas.DataFrame

# %%
type(df["idade"])

# %%
df.iloc[0:4, 1:3]
# Out:
#    idade   curso
# 0     22  Python
# 1     25    Java
# 2     21  Python
# 3     24      C#

# %%
type(df.iloc[[1,3,5], [0, 3]])
# Out:
# pandas.DataFrame

# %%
type(df.iloc[[1], [0]])
# Out:
# pandas.DataFrame

# %%
type(df.iloc[1, 0])
# Out:
# str

# %%
df.iloc[[1,2,5]]
# Out:
#      nome  idade   curso  nota  horas_estudo
# 1   Bruno     25    Java    14            15
# 2  Carlos     21  Python    12            10
# 5  Filipa     26    Java    16            18

# %%
df.loc[[2, 1,5], ["nome","nota"]]
# Out:
#      nome  nota
# 2  Carlos    12
# 1   Bruno    14
# 5  Filipa    16

# %%
df[df.nota > 15]
# Out:
#      nome  idade   curso  nota  horas_estudo
# 0     Ana     22  Python    17            20
# 3   Diana     24      C#    18            25
# 5  Filipa     26    Java    16            18

# %%
df[(df.nota > 15) & (df.horas_estudo < 20) ]
# Out:
#      nome  idade curso  nota  horas_estudo
# 5  Filipa     26  Java    16            18

# %%
df[(df.nota > 15) | (df.horas_estudo < 11) ]
# Out:
#       nome  idade   curso  nota  horas_estudo
# 0      Ana     22  Python    17            20
# 2   Carlos     21  Python    12            10
# 3    Diana     24      C#    18            25
# 4  Eduardo     23  Python    10             8
# 5   Filipa     26    Java    16            18

# %%
df[(df.curso == "Java") | (df.curso == "C#") ]
# Out:
#      nome  idade curso  nota  horas_estudo
# 1   Bruno     25  Java    14            15
# 3   Diana     24    C#    18            25
# 5  Filipa     26  Java    16            18

# %%
df.sort_values("horas_estudo", ascending=False ,inplace=True)

# %%
df
# Out:
#       nome  idade   curso  nota  horas_estudo
# 3    Diana     24      C#    18            25
# 0      Ana     22  Python    17            20
# 5   Filipa     26    Java    16            18
# 1    Bruno     25    Java    14            15
# 2   Carlos     21  Python    12            10
# 4  Eduardo     23  Python    10             8

# %%
df.sort_values(["curso", "nota"], ascending=(False, True))
# Out:
#       nome  idade   curso  nota  horas_estudo
# 4  Eduardo     23  Python    10             8
# 2   Carlos     21  Python    12            10
# 0      Ana     22  Python    17            20
# 1    Bruno     25    Java    14            15
# 5   Filipa     26    Java    16            18
# 3    Diana     24      C#    18            25

# %%
df.sort_index(inplace=True)
df
# Out:
#       nome  idade   curso  nota  horas_estudo
# 0      Ana     22  Python    17            20
# 1    Bruno     25    Java    14            15
# 2   Carlos     21  Python    12            10
# 3    Diana     24      C#    18            25
# 4  Eduardo     23  Python    10             8
# 5   Filipa     26    Java    16            18
